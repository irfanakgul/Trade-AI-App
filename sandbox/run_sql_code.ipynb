# %%
from db_connector import fn_cloud_read_table_where_symbol,fn_read_data_cloud,fn_write_cloud,run_postgres_sql
# Out:
# ========| ('irfan_admin', 'trade_app') |========
# *** ✅ SUCCESSFUL CLOUD CONNECTION ⛓️ ***

# %%
for exc in ["ams", "bist", "nasdaq", "nyse", "crypto", "assets"]:
    sql_text = f"""
DROP TABLE IF EXISTS gold."{exc}_master_final_combined";

CREATE TABLE gold."{exc}_master_final_combined" (
    "EXCHANGE" text NOT NULL,
    "SYMBOL" text NOT NULL,

    "FRVP_INTERVAL" text NULL,
    "FRVP_PERIOD_TYPE" text NULL,
    "FRVP_HIGHEST_DATE" timestamp NULL,
    "FRVP_HIGHEST_VALUE" double precision NULL,
    "FRVP_ROW_COUNT_AFTER_HIGHEST" integer NULL,
    "FRVP_DAY_COUNT_AFTER_HIGHEST" integer NULL,
    "FRVP_LATEST_CLOSE_VALUE" double precision NULL,
    "FRVP_POC" double precision NULL,
    "FRVP_VAL" double precision NULL,
    "FRVP_VAH" double precision NULL,

    "BS_OPEN_PRICE" double precision NULL,
    "BS_CLOSE_PRICE" double precision NULL,
    "BS_DIFFER" double precision NULL,
    "BS_PERC" double precision NULL,
    "BS_BAR_STATUS" text NULL,

    "RAW_END_DATE" timestamp NULL,
    "BRONZE_END_DATE" timestamp NULL,
    "SILVER_END_DATE" timestamp NULL,
    "SILVER_CONVERTED_END_DATE" timestamp NULL,
    "EXPECTED_END_DATE" timestamp NULL,

    "EMA_TIMESTAMP" timestamp NULL,
    "EMA_END_DATE" timestamp NULL,
    "EMA3" double precision NULL,
    "EMA5" double precision NULL,
    "EMA14" double precision NULL,
    "EMA20" double precision NULL,
    "EMA_STATUS_5_20" text NULL,
    "EMA_CROSS_5_20" text NULL,
    "EMA_STATUS_3_20" text NULL,
    "EMA_CROSS_3_20" text NULL,
    "EMA_STATUS_3_14" text NULL,
    "EMA_CROSS_3_14" text NULL,
    "EMA_DAYS_SINCE_CROSS_5_20" integer NULL,
    "EMA_DAYS_SINCE_CROSS_3_20" integer NULL,
    "EMA_DAYS_SINCE_CROSS_3_14" integer NULL,

    "RSI" double precision NULL,
    "RSI_MA" double precision NULL,
    "RSI_STATUS" text NULL,
    "RSI_CROSS" text NULL,
    "RSI_CROSS_DAYS_AGO" integer NULL,

    "MFI" double precision NULL,
    "MFI_YESTERDAY" double precision NULL,
    "MFI_12DAY_AVG" double precision NULL,
    "MFI_DIRECTION" text NULL,

    "VWAP_HIGHEST_VALUE" double precision NULL,
    "VWAP_HIGHEST_TIMESTAMP" timestamp NULL,
    "VWAP" double precision NULL,
    "VOL_AVG_5DAY" double precision NULL,
    "VOL_AVG_10DAY" double precision NULL,
    "VOL_AVG_20DAY" double precision NULL,
    "VOL_YESTERDAY" double precision NULL,
    "VOL_LASTDAY" double precision NULL,
    "VOL_STATUS" text NULL,

    "PVT_START_DATE" timestamp NULL,
    "PVT_END_DATE" timestamp NULL,
    "PVT_YEAR" integer NULL,
    "PIVOT" double precision NULL,
    "PVT_R1" double precision NULL,
    "PVT_R2" double precision NULL,
    "PVT_R3" double precision NULL,
    "PVT_R4" double precision NULL,
    "PVT_R5" double precision NULL,
    "PVT_S1" double precision NULL,
    "PVT_S2" double precision NULL,
    "PVT_S3" double precision NULL,
    "PVT_S4" double precision NULL,
    "PVT_S5" double precision NULL,
    "PVT_STATUS" text NULL,

    "POC_FRVP_STATUS" double precision NULL,
    "VWAP_STATUS" double precision NULL,
    "EMA_STATUS" double precision NULL,
    "RSI_STATUS_TXT" double precision NULL,
    "MFI_STATUS" bigint NULL,
    "VOL_STATUS_TXT" bigint NULL,
    "MASTER_SCORE" double precision NULL,

    "TRIAGE_ENTRY_DAY" text NULL,
    "TRIAGE_SCORE" numeric NULL,
    "RANK" integer NULL,
    "VALID_CLUSTER_COUNT" integer NULL,
    "AVG_POC" text NULL,
    "STOP_LOSS" text NULL,
    "TARGET_PRICE" text NULL,
    "STOP_LOSS_PERC" text NULL,
    "TARGET_PERC" text NULL,

    "CREATED_AT" timestamp NOT NULL,
    "CREATED_DAY" text NOT NULL,
    "RUNTIME" text NOT NULL
);

DROP TABLE IF EXISTS logs."logs_{exc}_master_final_combined";
CREATE TABLE logs."logs_{exc}_master_final_combined" (
    "EXCHANGE" text NOT NULL,
    "SYMBOL" text NOT NULL,

    "FRVP_INTERVAL" text NULL,
    "FRVP_PERIOD_TYPE" text NULL,
    "FRVP_HIGHEST_DATE" timestamp NULL,
    "FRVP_HIGHEST_VALUE" double precision NULL,
    "FRVP_ROW_COUNT_AFTER_HIGHEST" integer NULL,
    "FRVP_DAY_COUNT_AFTER_HIGHEST" integer NULL,
    "FRVP_LATEST_CLOSE_VALUE" double precision NULL,
    "FRVP_POC" double precision NULL,
    "FRVP_VAL" double precision NULL,
    "FRVP_VAH" double precision NULL,

    "BS_OPEN_PRICE" double precision NULL,
    "BS_CLOSE_PRICE" double precision NULL,
    "BS_DIFFER" double precision NULL,
    "BS_PERC" double precision NULL,
    "BS_BAR_STATUS" text NULL,

    "RAW_END_DATE" timestamp NULL,
    "BRONZE_END_DATE" timestamp NULL,
    "SILVER_END_DATE" timestamp NULL,
    "SILVER_CONVERTED_END_DATE" timestamp NULL,
    "EXPECTED_END_DATE" timestamp NULL,

    "EMA_TIMESTAMP" timestamp NULL,
    "EMA_END_DATE" timestamp NULL,
    "EMA3" double precision NULL,
    "EMA5" double precision NULL,
    "EMA14" double precision NULL,
    "EMA20" double precision NULL,
    "EMA_STATUS_5_20" text NULL,
    "EMA_CROSS_5_20" text NULL,
    "EMA_STATUS_3_20" text NULL,
    "EMA_CROSS_3_20" text NULL,
    "EMA_STATUS_3_14" text NULL,
    "EMA_CROSS_3_14" text NULL,
    "EMA_DAYS_SINCE_CROSS_5_20" integer NULL,
    "EMA_DAYS_SINCE_CROSS_3_20" integer NULL,
    "EMA_DAYS_SINCE_CROSS_3_14" integer NULL,

    "RSI" double precision NULL,
    "RSI_MA" double precision NULL,
    "RSI_STATUS" text NULL,
    "RSI_CROSS" text NULL,
    "RSI_CROSS_DAYS_AGO" integer NULL,

    "MFI" double precision NULL,
    "MFI_YESTERDAY" double precision NULL,
    "MFI_12DAY_AVG" double precision NULL,
    "MFI_DIRECTION" text NULL,

    "VWAP_HIGHEST_VALUE" double precision NULL,
    "VWAP_HIGHEST_TIMESTAMP" timestamp NULL,
    "VWAP" double precision NULL,
    "VOL_AVG_5DAY" double precision NULL,
    "VOL_AVG_10DAY" double precision NULL,
    "VOL_AVG_20DAY" double precision NULL,
    "VOL_YESTERDAY" double precision NULL,
    "VOL_LASTDAY" double precision NULL,
    "VOL_STATUS" text NULL,

    "PVT_START_DATE" timestamp NULL,
    "PVT_END_DATE" timestamp NULL,
    "PVT_YEAR" integer NULL,
    "PIVOT" double precision NULL,
    "PVT_R1" double precision NULL,
    "PVT_R2" double precision NULL,
    "PVT_R3" double precision NULL,
    "PVT_R4" double precision NULL,
    "PVT_R5" double precision NULL,
    "PVT_S1" double precision NULL,
    "PVT_S2" double precision NULL,
    "PVT_S3" double precision NULL,
    "PVT_S4" double precision NULL,
    "PVT_S5" double precision NULL,
    "PVT_STATUS" text NULL,

    "POC_FRVP_STATUS" double precision NULL,
    "VWAP_STATUS" double precision NULL,
    "EMA_STATUS" double precision NULL,
    "RSI_STATUS_TXT" double precision NULL,
    "MFI_STATUS" bigint NULL,
    "VOL_STATUS_TXT" bigint NULL,
    "MASTER_SCORE" double precision NULL,

    "TRIAGE_ENTRY_DAY" text NULL,
    "TRIAGE_SCORE" numeric NULL,
    "RANK" integer NULL,
    "VALID_CLUSTER_COUNT" integer NULL,
    "AVG_POC" text NULL,
    "STOP_LOSS" text NULL,
    "TARGET_PRICE" text NULL,
    "STOP_LOSS_PERC" text NULL,
    "TARGET_PERC" text NULL,

    "CREATED_AT" timestamp NOT NULL,
    "CREATED_DAY" text NOT NULL,
    "RUNTIME" text NOT NULL
);




"""
    r = run_postgres_sql(sql_text, fetch=False)
    print(exc, r)

print("✅")
# Out:
# ams {'status': 'ok', 'rowcount': -1}
# bist {'status': 'ok', 'rowcount': -1}
# nasdaq {'status': 'ok', 'rowcount': -1}
# nyse {'status': 'ok', 'rowcount': -1}
# crypto {'status': 'ok', 'rowcount': -1}
# assets {'status': 'ok', 'rowcount': -1}
# ✅

# %%
import pandas as pd

sql = """
SELECT *
FROM gold."bist_master_combined_indicators" m
LEFT JOIN gold."bist_ind_all_scores" s
    ON m."EXCHANGE" = s."EXCHANGE"
   AND m."SYMBOL" = s."SYMBOL"
   AND m."FRVP_PERIOD_TYPE" = s."FRVP_PERIOD_TYPE"
LEFT JOIN gold."bist_evaluation_master_score" e
    ON m."EXCHANGE" = e."EXCHANGE"
   AND m."SYMBOL" = e."SYMBOL"
"""

rows = run_postgres_sql(sql)

df = pd.DataFrame(rows)

# %%
for i in df.columns:
    print(i)
# Out:
# EXCHANGE
# SYMBOL
# FRVP_INTERVAL
# FRVP_PERIOD_TYPE
# FRVP_HIGHEST_DATE
# FRVP_HIGHEST_VALUE
# FRVP_ROW_COUNT_AFTER_HIGHEST
# FRVP_DAY_COUNT_AFTER_HIGHEST
# FRVP_LATEST_CLOSE_VALUE
# FRVP_POC
# FRVP_VAL
# FRVP_VAH
# BS_OPEN_PRICE
# BS_CLOSE_PRICE
# BS_DIFFER
# BS_PERC
# BS_BAR_STATUS
# RAW_END_DATE
# BRONZE_END_DATE
# SILVER_END_DATE
# SILVER_CONVERTED_END_DATE
# EXPECTED_END_DATE
# EMA_TIMESTAMP
# EMA_END_DATE
# EMA3
# EMA5
# EMA14
# EMA20
# EMA_STATUS_5_20
# EMA_CROSS_5_20
# EMA_STATUS_3_20
# EMA_CROSS_3_20
# EMA_STATUS_3_14
# EMA_CROSS_3_14
# EMA_DAYS_SINCE_CROSS_5_20
# EMA_DAYS_SINCE_CROSS_3_20
# EMA_DAYS_SINCE_CROSS_3_14
# RSI
# RSI_MA
# RSI_STATUS
# RSI_CROSS
# RSI_CROSS_DAYS_AGO
# MFI
# MFI_YESTERDAY
# MFI_12DAY_AVG
# MFI_DIRECTION
# VWAP_HIGHEST_VALUE
# VWAP_HIGHEST_TIMESTAMP
# VWAP
# VOL_AVG_5DAY
# VOL_AVG_10DAY
# VOL_AVG_20DAY
# VOL_YESTERDAY
# VOL_LASTDAY
# VOL_STATUS
# PVT_START_DATE
# PVT_END_DATE
# PVT_YEAR
# PIVOT
# PVT_R1
# PVT_R2
# PVT_R3
# PVT_R4
# PVT_R5
# PVT_S1
# ...
